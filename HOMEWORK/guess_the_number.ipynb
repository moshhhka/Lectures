# %% [markdown]
# дан регион [-1000, 1000]
# пользователь загадал какое-то целое число
#
# задача программы - замучать пользователя вопросами;
# определить середину региона и спросить у пользователя:
#     число <, > или == этой середине
# если == - победа
# если < или > - отсекаем ненужную половину региона
# если пользователь написал exit - выйти из программы
# программа считается работающей, если мы в итоге находим число
#
# доп балл за возможность ввести регион в начале программы

# %%
from rich import print as rprint

rprint('[bold yellow] Guess the number form -1000 to 1000')

low = -1000
high = 1000

while low <= high:
    mid = (high + low) // 2
    print(mid)
    print(f'Your number > < = {mid}? :')
    attempt = input()
    print(attempt)
    
    if attempt == '=':
        rprint(f'[bold green]Yeeey! Your number is {mid} !')
        break
    elif attempt == '>':
        low = mid + 1
    elif attempt == '<':
        high = mid - 1
    else:
        print('CaT! Get away from keyboard')
# Out:
#  Guess the number form -1000 to 1000
# 0
# Your number > < = 0? :
# >
# 500
# Your number > < = 500? :
# <
# 250
# Your number > < = 250? :
# <
# 125
# Your number > < = 125? :
# >
# 187
# Your number > < = 187? :
# >
# 218
# Your number > < = 218? :
# <
# 202
# Your number > < = 202? :
# <
# 194
# Your number > < = 194? :
# =
# Yeeey! Your number is 194 !
